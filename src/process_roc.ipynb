# %%
import pandas as pd
import numpy as np

pd.set_option('mode.chained_assignment', None)

df = pd.read_csv(r"E:\Tung\Python\VcreamProject\cache\ALL.csv")

df.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %% [markdown]
# ROC: Rate of change
#
# ROC=[((Close price today - Close price "n" days ago)/Close price "n" days ago))]
#
# n = 5, 10, 20, 40, 80 days

# %%
vcb = df.loc[df['Ticker'] == 'VCB']
vcb.head(10)
# Out:
#         Ticker        Date     Open     High      Low    Close   Volume
# 2026933    VCB  2009-06-30  16.2420  16.2420  16.2420  16.2452   294070
# 2026934    VCB  2009-07-01  17.0541  17.0541  16.1067  16.3806  6248390
# 2026935    VCB  2009-07-02  16.1067  16.2420  15.5653  15.7037  1515670
# 2026936    VCB  2009-07-03  15.2946  15.4299  15.1592  15.1622   899720
# 2026937    VCB  2009-07-06  15.1592  15.8360  15.1592  15.8391  1571740
# 2026938    VCB  2009-07-07  15.5653  15.7006  15.2946  15.2976  1115420
# 2026939    VCB  2009-07-08  14.8885  15.1592  14.7532  15.0269   763030
# 2026940    VCB  2009-07-09  14.7532  15.1592  14.4825  14.6207   982430
# 2026941    VCB  2009-07-10  14.3471  14.4825  13.9411  13.9438  1973450
# 2026942    VCB  2009-07-13  13.5350  13.9411  13.2643  13.2670   812260

# %%
vcb['roc_5'] = vcb['Close'].diff(5)/vcb['Close'].shift(5)
vcb['roc_10'] = vcb['Close'].diff(10)/vcb['Close'].shift(10)
vcb['roc_20'] = vcb['Close'].diff(20)/vcb['Close'].shift(20)

vcb.head(20)
# Out:
#         Ticker        Date     Open     High      Low    Close   Volume  \
# 2026933    VCB  2009-06-30  16.2420  16.2420  16.2420  16.2452   294070
# 2026934    VCB  2009-07-01  17.0541  17.0541  16.1067  16.3806  6248390
# 2026935    VCB  2009-07-02  16.1067  16.2420  15.5653  15.7037  1515670
# 2026936    VCB  2009-07-03  15.2946  15.4299  15.1592  15.1622   899720
# 2026937    VCB  2009-07-06  15.1592  15.8360  15.1592  15.8391  1571740
# 2026938    VCB  2009-07-07  15.5653  15.7006  15.2946  15.2976  1115420
# 2026939    VCB  2009-07-08  14.8885  15.1592  14.7532  15.0269   763030
# 2026940    VCB  2009-07-09  14.7532  15.1592  14.4825  14.6207   982430
# 2026941    VCB  2009-07-10  14.3471  14.4825  13.9411  13.9438  1973450
# 2026942    VCB  2009-07-13  13.5350  13.9411  13.2643  13.2670   812260
# 2026943    VCB  2009-07-14  13.3184  13.3184  12.8583  12.9420   847840
# 2026944    VCB  2009-07-15  12.9936  13.4809  12.9936  13.2670   807250
# ...

# %%
df['roc_5'] = df.groupby('Ticker')['Close'].diff(5)/df.groupby('Ticker')['Close'].shift(5)
df['roc_10'] = df.groupby('Ticker')['Close'].diff(10)/df.groupby('Ticker')['Close'].shift(10)
df['roc_20'] = df.groupby('Ticker')['Close'].diff(20)/df.groupby('Ticker')['Close'].shift(20)
df['roc_40'] = df.groupby('Ticker')['Close'].diff(40)/df.groupby('Ticker')['Close'].shift(40)
df['roc_80'] = df.groupby('Ticker')['Close'].diff(80)/df.groupby('Ticker')['Close'].shift(80)

df
# Out:
#         Ticker        Date     Open     High      Low    Close  Volume  \
# 0          A32  2018-11-29  22.9056  22.9056  22.9056  22.9076    1000
# 1          A32  2018-12-03  22.9056  22.9056  22.9056  22.9076     100
# 2          A32  2018-12-04  20.0424  20.0424  20.0424  20.0441    2000
# 3          A32  2018-12-21  21.6172  21.6172  21.6172  21.6190     100
# 4          A32  2019-01-02  22.9056  22.9056  22.9056  22.9076     100
# ...        ...         ...      ...      ...      ...      ...     ...
# 2274182    YTC  2022-05-12  68.0000  68.0000  68.0000  68.0000     100
# 2274183    YTC  2022-06-15  66.0000  66.0000  65.0000  65.0000     200
# 2274184    YTC  2022-06-24  65.5000  65.5000  65.5000  65.5000      10
# 2274185    YTC  2022-09-05  65.5000  65.5000  65.5000  65.5000     200
# 2274186    YTC  2022-10-04  65.5000  65.5000  65.5000  65.5000       1
#
#             roc_5    roc_10    roc_20    roc_40    roc_80
# ...

# %%
df.loc[df['Ticker'] == 'VCB'].head(20)
# Out:
#         Ticker        Date     Open     High      Low    Close   Volume  \
# 2026933    VCB  2009-06-30  16.2420  16.2420  16.2420  16.2452   294070
# 2026934    VCB  2009-07-01  17.0541  17.0541  16.1067  16.3806  6248390
# 2026935    VCB  2009-07-02  16.1067  16.2420  15.5653  15.7037  1515670
# 2026936    VCB  2009-07-03  15.2946  15.4299  15.1592  15.1622   899720
# 2026937    VCB  2009-07-06  15.1592  15.8360  15.1592  15.8391  1571740
# 2026938    VCB  2009-07-07  15.5653  15.7006  15.2946  15.2976  1115420
# 2026939    VCB  2009-07-08  14.8885  15.1592  14.7532  15.0269   763030
# 2026940    VCB  2009-07-09  14.7532  15.1592  14.4825  14.6207   982430
# 2026941    VCB  2009-07-10  14.3471  14.4825  13.9411  13.9438  1973450
# 2026942    VCB  2009-07-13  13.5350  13.9411  13.2643  13.2670   812260
# 2026943    VCB  2009-07-14  13.3184  13.3184  12.8583  12.9420   847840
# 2026944    VCB  2009-07-15  12.9936  13.4809  12.9936  13.2670   807250
# ...

# %%
def roc(panel_data):
    panel_data['roc_5'] = panel_data.groupby('Ticker')['Close'].diff(5)/panel_data.groupby('Ticker')['Close'].shift(5)
    panel_data['roc_10'] = panel_data.groupby('Ticker')['Close'].diff(10)/panel_data.groupby('Ticker')['Close'].shift(10)
    panel_data['roc_20'] = panel_data.groupby('Ticker')['Close'].diff(20)/panel_data.groupby('Ticker')['Close'].shift(20)
    panel_data['roc_40'] = panel_data.groupby('Ticker')['Close'].diff(40)/panel_data.groupby('Ticker')['Close'].shift(40)
    panel_data['roc_80'] = panel_data.groupby('Ticker')['Close'].diff(80)/panel_data.groupby('Ticker')['Close'].shift(80)

    return panel_data

# %%
df = roc(panel_data=df)
df
# Out:
#         Ticker        Date     Open     High      Low    Close  Volume  \
# 0          A32  2018-11-29  22.9056  22.9056  22.9056  22.9076    1000
# 1          A32  2018-12-03  22.9056  22.9056  22.9056  22.9076     100
# 2          A32  2018-12-04  20.0424  20.0424  20.0424  20.0441    2000
# 3          A32  2018-12-21  21.6172  21.6172  21.6172  21.6190     100
# 4          A32  2019-01-02  22.9056  22.9056  22.9056  22.9076     100
# ...        ...         ...      ...      ...      ...      ...     ...
# 2274182    YTC  2022-05-12  68.0000  68.0000  68.0000  68.0000     100
# 2274183    YTC  2022-06-15  66.0000  66.0000  65.0000  65.0000     200
# 2274184    YTC  2022-06-24  65.5000  65.5000  65.5000  65.5000      10
# 2274185    YTC  2022-09-05  65.5000  65.5000  65.5000  65.5000     200
# 2274186    YTC  2022-10-04  65.5000  65.5000  65.5000  65.5000       1
#
#             roc_5    roc_10    roc_20    roc_40    roc_80
# ...
