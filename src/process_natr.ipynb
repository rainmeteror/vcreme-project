# %%
import pandas as pd
import numpy as np

pd.set_option('mode.chained_assignment', None)

df = pd.read_csv(r"E:\Tung\Python\VcreamProject\cache\ALL.csv")

df.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %% [markdown]
# NATR: 10, 15, 20 days

# %%
df
# Out:
#         Ticker        Date     Open     High      Low    Close  Volume
# 0          A32  2018-11-29  22.9056  22.9056  22.9056  22.9076    1000
# 1          A32  2018-12-03  22.9056  22.9056  22.9056  22.9076     100
# 2          A32  2018-12-04  20.0424  20.0424  20.0424  20.0441    2000
# 3          A32  2018-12-21  21.6172  21.6172  21.6172  21.6190     100
# 4          A32  2019-01-02  22.9056  22.9056  22.9056  22.9076     100
# ...        ...         ...      ...      ...      ...      ...     ...
# 2274182    YTC  2022-05-12  68.0000  68.0000  68.0000  68.0000     100
# 2274183    YTC  2022-06-15  66.0000  66.0000  65.0000  65.0000     200
# 2274184    YTC  2022-06-24  65.5000  65.5000  65.5000  65.5000      10
# 2274185    YTC  2022-09-05  65.5000  65.5000  65.5000  65.5000     200
# 2274186    YTC  2022-10-04  65.5000  65.5000  65.5000  65.5000       1
#
# [2274187 rows x 7 columns]

# %%
vcb = df.loc[df['Ticker'] == 'VCB']
vcb
# Out:
#         Ticker        Date     Open     High      Low    Close   Volume
# 2026933    VCB  2009-06-30  16.2420  16.2420  16.2420  16.2452   294070
# 2026934    VCB  2009-07-01  17.0541  17.0541  16.1067  16.3806  6248390
# 2026935    VCB  2009-07-02  16.1067  16.2420  15.5653  15.7037  1515670
# 2026936    VCB  2009-07-03  15.2946  15.4299  15.1592  15.1622   899720
# 2026937    VCB  2009-07-06  15.1592  15.8360  15.1592  15.8391  1571740
# ...        ...         ...      ...      ...      ...      ...      ...
# 2030248    VCB  2022-10-10  66.5000  67.7000  64.1000  65.1000  1317000
# 2030249    VCB  2022-10-11  65.3000  66.0000  62.0000  62.0000  1161700
# 2030250    VCB  2022-10-12  63.0000  65.3000  62.2000  64.0000  1517400
# 2030251    VCB  2022-10-13  64.1000  66.5000  62.7000  66.5000  1596800
# 2030252    VCB  2022-10-14  68.5000  68.5000  67.3000  68.1000  1599300
#
# [3320 rows x 7 columns]

# %%
vcb['previous_close'] = vcb['Close'].shift(1)
vcb['high-low'] = vcb['High'] - vcb['Low']
vcb['high-pc'] = np.abs(vcb['High'] - vcb['previous_close'])
vcb['low-pc'] = np.abs(vcb['Low'] - vcb['previous_close'])

vcb['true_range'] = np.max(vcb[['high-low', 'high-pc', 'low-pc']], axis=1)
vcb['atr_10'] = vcb['true_range'].rolling(10).mean()
vcb['atr_15'] = vcb['true_range'].rolling(15).mean()
vcb['atr_20'] = vcb['true_range'].rolling(20).mean()


vcb['natr_10'] = vcb['atr_10']/vcb['Close']*100
vcb['natr_15'] = vcb['atr_15']/vcb['Close']*100
vcb['natr_20'] = vcb['atr_20']/vcb['Close']*100

vcb
# Out:
#         Ticker        Date     Open     High      Low    Close   Volume  \
# 2026933    VCB  2009-06-30  16.2420  16.2420  16.2420  16.2452   294070
# 2026934    VCB  2009-07-01  17.0541  17.0541  16.1067  16.3806  6248390
# 2026935    VCB  2009-07-02  16.1067  16.2420  15.5653  15.7037  1515670
# 2026936    VCB  2009-07-03  15.2946  15.4299  15.1592  15.1622   899720
# 2026937    VCB  2009-07-06  15.1592  15.8360  15.1592  15.8391  1571740
# ...        ...         ...      ...      ...      ...      ...      ...
# 2030248    VCB  2022-10-10  66.5000  67.7000  64.1000  65.1000  1317000
# 2030249    VCB  2022-10-11  65.3000  66.0000  62.0000  62.0000  1161700
# 2030250    VCB  2022-10-12  63.0000  65.3000  62.2000  64.0000  1517400
# 2030251    VCB  2022-10-13  64.1000  66.5000  62.7000  66.5000  1596800
# 2030252    VCB  2022-10-14  68.5000  68.5000  67.3000  68.1000  1599300
#
#          previous_close  high-low  high-pc  low-pc  true_range  atr_10  \
# ...

# %%
df['previous_close'] = df.groupby('Ticker')['Close'].shift(1)
df['high-low'] = df['High'] - df['Low']
df['high-pc'] = np.abs(df['High'] - df['previous_close'])
df['low-pc'] = np.abs(df['Low'] - df['previous_close'])
df['true_range'] = np.max(df[['high-low', 'high-pc', 'low-pc']], axis=1)

df['atr_10'] = df.groupby('Ticker')['true_range'].rolling(10).mean().reset_index(drop=True).to_list()
df['atr_15'] = df.groupby('Ticker')['true_range'].rolling(15).mean().reset_index(drop=True).to_list()
df['atr_20'] = df.groupby('Ticker')['true_range'].rolling(20).mean().reset_index(drop=True).to_list()


df['natr_10'] = df['atr_10']/df['Close']*100
df['natr_15'] = df['atr_15']/df['Close']*100
df['natr_20'] = df['atr_20']/df['Close']*100

df
# Out:
#         Ticker        Date     Open     High      Low    Close  Volume  \
# 0          A32  2018-11-29  22.9056  22.9056  22.9056  22.9076    1000
# 1          A32  2018-12-03  22.9056  22.9056  22.9056  22.9076     100
# 2          A32  2018-12-04  20.0424  20.0424  20.0424  20.0441    2000
# 3          A32  2018-12-21  21.6172  21.6172  21.6172  21.6190     100
# 4          A32  2019-01-02  22.9056  22.9056  22.9056  22.9076     100
# ...        ...         ...      ...      ...      ...      ...     ...
# 2274182    YTC  2022-05-12  68.0000  68.0000  68.0000  68.0000     100
# 2274183    YTC  2022-06-15  66.0000  66.0000  65.0000  65.0000     200
# 2274184    YTC  2022-06-24  65.5000  65.5000  65.5000  65.5000      10
# 2274185    YTC  2022-09-05  65.5000  65.5000  65.5000  65.5000     200
# 2274186    YTC  2022-10-04  65.5000  65.5000  65.5000  65.5000       1
#
#          previous_close  high-low  high-pc  low-pc  true_range  atr_10  \
# ...

# %%
def natr(panel_data):
    panel_data['previous_close'] = panel_data.groupby('Ticker')['Close'].shift(1)
    panel_data['high-low'] = panel_data['High'] - panel_data['Low']
    panel_data['high-pc'] = np.abs(panel_data['High'] - panel_data['previous_close'])
    panel_data['low-pc'] = np.abs(panel_data['Low'] - panel_data['previous_close'])
    panel_data['true_range'] = np.max(panel_data[['high-low', 'high-pc', 'low-pc']], axis=1)

    panel_data['atr_10'] = panel_data.groupby('Ticker')['true_range'].rolling(10).mean().reset_index(drop=True).to_list()
    panel_data['atr_15'] = panel_data.groupby('Ticker')['true_range'].rolling(15).mean().reset_index(drop=True).to_list()
    panel_data['atr_20'] = panel_data.groupby('Ticker')['true_range'].rolling(20).mean().reset_index(drop=True).to_list()

    panel_data['natr_10'] = panel_data['atr_10']/panel_data['Close']*100
    panel_data['natr_15'] = panel_data['atr_15']/panel_data['Close']*100
    panel_data['natr_20'] = panel_data['atr_20']/panel_data['Close']*100
    
    del panel_data['previous_close']
    del panel_data['high-low']
    del panel_data['high-pc']
    del panel_data['low-pc']
    del panel_data['true_range']
    del panel_data['atr_10']
    del panel_data['atr_15']
    del panel_data['atr_20']

    return panel_data

# %%
df = natr(panel_data=df)
df
# Out:
#         Ticker        Date     Open     High      Low    Close  Volume  \
# 0          A32  2018-11-29  22.9056  22.9056  22.9056  22.9076    1000
# 1          A32  2018-12-03  22.9056  22.9056  22.9056  22.9076     100
# 2          A32  2018-12-04  20.0424  20.0424  20.0424  20.0441    2000
# 3          A32  2018-12-21  21.6172  21.6172  21.6172  21.6190     100
# 4          A32  2019-01-02  22.9056  22.9056  22.9056  22.9076     100
# ...        ...         ...      ...      ...      ...      ...     ...
# 2274182    YTC  2022-05-12  68.0000  68.0000  68.0000  68.0000     100
# 2274183    YTC  2022-06-15  66.0000  66.0000  65.0000  65.0000     200
# 2274184    YTC  2022-06-24  65.5000  65.5000  65.5000  65.5000      10
# 2274185    YTC  2022-09-05  65.5000  65.5000  65.5000  65.5000     200
# 2274186    YTC  2022-10-04  65.5000  65.5000  65.5000  65.5000       1
#
#           natr_10   natr_15   natr_20
# 0             NaN       NaN       NaN
# ...
